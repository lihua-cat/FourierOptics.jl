# %%
using Revise

# %%
using FourierOptics

# %%
L = 10
N = 1024
λ = [450, 500]
E = rand(N)
CoherentField1D(L, N, λ, E; T = Float64)
# Out:
# 1024-element CoherentField1D{Float64}:
#  (x = -5.0, E = ComplexF64[0.6183009414796881 + 0.0im, 0.6183009414796881 + 0.0im])
#  (x = -4.990234375, E = ComplexF64[0.37050637934189 + 0.0im, 0.37050637934189 + 0.0im])
#  (x = -4.98046875, E = ComplexF64[0.7453352457627014 + 0.0im, 0.7453352457627014 + 0.0im])
#  (x = -4.970703125, E = ComplexF64[0.8152764455538501 + 0.0im, 0.8152764455538501 + 0.0im])
#  (x = -4.9609375, E = ComplexF64[0.1161631885596337 + 0.0im, 0.1161631885596337 + 0.0im])
#  (x = -4.951171875, E = ComplexF64[0.4825469092733161 + 0.0im, 0.4825469092733161 + 0.0im])
#  (x = -4.94140625, E = ComplexF64[0.7748399207584278 + 0.0im, 0.7748399207584278 + 0.0im])
#  (x = -4.931640625, E = ComplexF64[0.46156731841003085 + 0.0im, 0.46156731841003085 + 0.0im])
#  (x = -4.921875, E = ComplexF64[0.08986310172549916 + 0.0im, 0.08986310172549916 + 0.0im])
#  (x = -4.912109375, E = ComplexF64[0.12975769405431548 + 0.0im, 0.12975769405431548 + 0.0im])
#  ⋮
# ...

# %%
L = (10, 10)
N = (1024, 1024)
λ = [450.0, 500.0]
E = rand(N...) .* [1;;;0.5]
# Out:
# 1024×1024×2 Array{Float64, 3}:
# [:, :, 1] =
#  0.493366   0.748797   0.877215   …  0.537229   0.0691009  0.776242
#  0.842478   0.161657   0.0134902     0.32418    0.734204   0.877803
#  0.0934294  0.8261     0.208831      0.583079   0.987827   0.801143
#  0.689323   0.569496   0.783768      0.144963   0.86069    0.771925
#  0.211735   0.025363   0.609831      0.378403   0.489908   0.0313415
#  0.298668   0.136366   0.490819   …  0.122856   0.456269   0.34551
#  0.17915    0.423219   0.882397      0.964038   0.384348   0.895995
#  0.323806   0.793592   0.0781734     0.0407232  0.619219   0.412349
#  0.563805   0.550716   0.181673      0.75358    0.341805   0.845731
#  0.350091   0.272549   0.0620251     0.525412   0.0236121  0.214815
#  ⋮                                ⋱
#  0.566946   0.873854   0.855653   …  0.313859   0.280696   0.452001
#  0.965807   0.76762    0.407688      0.640587   0.104386   0.13485
#  0.441906   0.502577   0.972187      0.859678   0.259405   0.53722
# ...

# %%
u = CoherentField2D(L, N, λ, E; T = Float64)
# Out:
# 1024×1024 CoherentField2D{Float64}:
#  (x = -5.0, y = -5.0, E = ComplexF64[0.493366+0.0im, 0.246683+0.0im])        …  (x = -5.0, y = 4.99023, E = ComplexF64[0.776242+0.0im, 0.388121+0.0im])
#  (x = -4.99023, y = -5.0, E = ComplexF64[0.842478+0.0im, 0.421239+0.0im])       (x = -4.99023, y = 4.99023, E = ComplexF64[0.877803+0.0im, 0.438902+0.0im])
#  (x = -4.98047, y = -5.0, E = ComplexF64[0.0934294+0.0im, 0.0467147+0.0im])     (x = -4.98047, y = 4.99023, E = ComplexF64[0.801143+0.0im, 0.400572+0.0im])
#  (x = -4.9707, y = -5.0, E = ComplexF64[0.689323+0.0im, 0.344662+0.0im])        (x = -4.9707, y = 4.99023, E = ComplexF64[0.771925+0.0im, 0.385963+0.0im])
#  (x = -4.96094, y = -5.0, E = ComplexF64[0.211735+0.0im, 0.105868+0.0im])       (x = -4.96094, y = 4.99023, E = ComplexF64[0.0313415+0.0im, 0.0156708+0.0im])
#  (x = -4.95117, y = -5.0, E = ComplexF64[0.298668+0.0im, 0.149334+0.0im])    …  (x = -4.95117, y = 4.99023, E = ComplexF64[0.34551+0.0im, 0.172755+0.0im])
# ...
